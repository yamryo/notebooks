# %%
class PrimeList(list):
    def __init__(self):
        self = []
    def generate(self, n):
        del self[:]
        for num in range(2,n+1):
            if is_prime(num):
                self.append(num)
        return self

# %%
a = PrimeList(); 
# %time len(a.generate(1000))
# Out:
# CPU times: user 5.01 ms, sys: 922 µs, total: 5.93 ms
# Wall time: 5.16 ms
# 168

# %%
N = 10000; B = 1.08366; switch = 0;

plist = a.generate(N); plist
datalist = [(k,len([x for x in plist if x <= k])) for k in range(3,N+1,int(N/100))]
G1 = list_plot(datalist, pointsize = 1)

Li(x) = x/(log(x)-B*switch)
G2 = plot(Li,(x,3,N), color = "red")

var('u,t'); assume(t-2>0)
GI(t) = integral(1/log(u),(u,2,t)) #Ei(log(x)) #
G3 = plot(GI,(x,3,N), color = "green")

(G1+G2+G3).show(ymin=0,ymax=max([n[1] for n in datalist])*1.2)
# Out:
# /Applications/SageMath-8.2.app/Contents/Resources/sage/local/lib/python2.7/site-packages/matplotlib/font_manager.py:279: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '
# Graphics object consisting of 3 graphics primitives

# %%
limit(Li(x)/GI(x),x=oo)
# Out:
# 1

# %%
N = 100000;
data = [(k,euler_phi(k)) for k in range(1,N+1,7)]
G4 = list_plot(data, pointsize = 1)

G4.show()

# %%
R.<x> = QQ[x]
1/(x+3)*1/(x-3)
# Out:
# 1/(x^2 - 9)

# %%
type(1/2)
# Out:
# <type 'sage.rings.rational.Rational'>

# %%
5 in range(2,200)
# Out:
# True

# %%
binomial(40,3)
# Out:
# 9880

# %%
N = 100; p=9; A, B = [], [];
for a in range(1, N+1):
    if (a%p != 0) and (power_mod(a, p-1, p) != 1):
#         print("There it is!! a={}".format(a))
        A.append(a)
    else:
        B.append(a)
# print("B={}".format(B))
print("A={}".format(A))
# Out:
# A=[2, 3, 4, 5, 6, 7, 11, 12, 13, 14, 15, 16, 20, 21, 22, 23, 24, 25, 29, 30, 31, 32, 33, 34, 38, 39, 40, 41, 42, 43, 47, 48, 49, 50, 51, 52, 56, 57, 58, 59, 60, 61, 65, 66, 67, 68, 69, 70, 74, 75, 76, 77, 78, 79, 83, 84, 85, 86, 87, 88, 92, 93, 94, 95, 96, 97]

# %%
show(DihedralGroup(8).cayley_graph())
# Out:
# Graphics object consisting of 64 graphics primitives

# %%
CombinatorialFreeModule?

# %%
H = CombinatorialFreeModule(QQ, [1,2,3,4], prefix='b'); b = H.basis();list(b)
# Out:
# [b[1], b[2], b[3], b[4]]

# %%
H.an_element()
# Out:
# 2*b[1] + 2*b[2] + 3*b[3]

# %%
elm1 = (1/2)*b[1]-(3/2)*b[3]; elm1 in H
elm2 = -2*b[1]+b[2]-(5/2)*b[3]+3*b[4]
elm1+elm2
# Out:
# -3/2*b[1] + b[2] - 4*b[3] + 3*b[4]

# %%
taylor(1/(1+x),x,0,4)
# Out:
# x^4 - x^3 + x^2 - x + 1

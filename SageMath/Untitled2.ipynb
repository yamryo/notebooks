# %%
t=var('t')
f(t) = ((1-t)-t)^2/((1-t)^2+t)
plot(f(t),(t,0,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# f(0.30132011)
f((1+sqrt(3/7))/2)
# Out:
# 12/7/((sqrt(3/7) - 1)^2 + 2*sqrt(3/7) + 2)

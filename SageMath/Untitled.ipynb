# %%
n = 12
th = pi/3/(n+1)
N( sin(th/2)*2 - 1/n)
# Out:
# -0.00280145311450306

# %%
list_plot([sin(pi/3/(n+1)/2)*2 - 1/n for n in range(2,50)])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
ml = [(N(pi/3/(n+1)), N(sin(pi/3/(n+1)/2)*2)) for n in range(10,50)]
# list_plot(ml)
for k in range(len(ml)):
    print(10+k, ml[k], ml[k][0]-ml[k][1])
# Out:
# (10, (0.0951997773815089, 0.0951638316474846), 0.0000359457340242952)
# (11, (0.0872664625997165, 0.0872387747306720), 0.0000276878690444737)
# (12, (0.0805536577843537, 0.0805318802188303), 0.0000217775655233926)
# (13, (0.0747998250854713, 0.0747823885526512), 0.0000174365328200199)
# (14, (0.0698131700797732, 0.0697989934050019), 0.0000141766747712435)
# (15, (0.0654498469497874, 0.0654381656435523), 0.0000116813062350785)
# (16, (0.0615998559527410, 0.0615901171123407), 9.73884040033485e-6)
# (17, (0.0581776417331443, 0.0581694374862228), 8.20424692150878e-6)
# (18, (0.0551156605892946, 0.0551086847363240), 6.97585297062403e-6)
# (19, (0.0523598775598299, 0.0523538966157463), 5.98094408358479e-6)
# (20, (0.0498665500569808, 0.0498613834761457), 5.16658083509619e-6)
# (21, (0.0475998886907544, 0.0475953950922150), 4.49359853941372e-6)
# (22, (0.0455303283128956, 0.0455263957122114), 3.93260068418805e-6)
# (23, (0.0436332312998582, 0.0436297700691222), 3.46123073599602e-6)
# ...

# %%
N(ml[30])
# Out:
# 0.0000284644867465378

# %%
list_plot([pi/3/(n+1) - 1/n for n in range(2,50)])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
mylist = [(n, 1.0472/(n+1), N(1/n)) for n in range(1,50+1)]
for c in mylist:
    print(c, c[1]>c[2])
# Out:
# ((1, 0.523600000000000, 1.00000000000000), False)
# ((2, 0.349066666666667, 0.500000000000000), False)
# ((3, 0.261800000000000, 0.333333333333333), False)
# ((4, 0.209440000000000, 0.250000000000000), False)
# ((5, 0.174533333333333, 0.200000000000000), False)
# ((6, 0.149600000000000, 0.166666666666667), False)
# ((7, 0.130900000000000, 0.142857142857143), False)
# ((8, 0.116355555555556, 0.125000000000000), False)
# ((9, 0.104720000000000, 0.111111111111111), False)
# ((10, 0.0952000000000000, 0.100000000000000), False)
# ((11, 0.0872666666666667, 0.0909090909090909), False)
# ((12, 0.0805538461538461, 0.0833333333333333), False)
# ((13, 0.0748000000000000, 0.0769230769230769), False)
# ((14, 0.0698133333333333, 0.0714285714285714), False)
# ((15, 0.0654500000000000, 0.0666666666666667), False)
# ((16, 0.0616000000000000, 0.0625000000000000), False)
# ((17, 0.0581777777777778, 0.0588235294117647), False)
# ((18, 0.0551157894736842, 0.0555555555555556), False)
# ...

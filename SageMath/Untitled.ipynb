# %%
W = CoxeterGroup(['H',3])
G = W.bruhat_graph(); G
# Digraph on 120 vertices
# Out:
# Digraph on 120 vertices (use the .plot() method to plot)

# %%
W = CoxeterGroup(['A',2,1])
s1, s2, s3 = W.simple_reflections()
W.bruhat_graph(s1, s1*s3*s2*s3)
# Digraph on 6 vertices
# Out:
# Digraph on 6 vertices

# %%
W.bruhat_graph(s1, s3*s2*s3)
# Digraph on 0 vertices
# Out:
# Digraph on 0 vertices (use the .plot() method to plot)

# %%
W = WeylGroup("A3", prefix="s")
s1, s2, s3 = W.simple_reflections()
G = W.bruhat_graph(s1*s3, s1*s2*s3*s2*s1); G
# Digraph on 10 vertices
# Out:
# Digraph on 10 vertices

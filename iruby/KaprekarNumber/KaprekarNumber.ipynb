# %% [markdown]
# # Kaprekar Numbers

# %% [markdown]
# ## Define Kaprekar Class

# %%
module Kaprekar_interface
  def get_next() end
  def sequence() end
  def find_loop() end
  
  def ==(kp) @number == kp.number end
  def inspect() @number end

  protected
  def split(num)
    raise ArgumentError unless num.is_a?(Integer)
    return num.to_s.split("")
  end
  def min(num) split(num).sort.join.to_i end
  def max(num) split(num).sort.reverse.join.to_i end
end

#-------------------------------------------------------#

class Kaprekar include Kaprekar_interface
  def initialize(num)
    @number = num
    @next = max(num) - min(num)
  end
  attr_reader :number, :next, :prevs
  
  def get_prevs()
    dgt = 10**(@number.to_s.size-1)
    rng = (dgt..dgt*10)
    return rng.to_a.select{|n| self.class.new(n).next == @number}
  end
  
  def sequence(count=200)
    seq = [self]
    while (seq.count(seq[-1]) < 2 and count > 0)
      seq << self.class.new(seq[-1].next)
      count -= 1
    end
    seq.pop 
    return seq
  end

  def find_loop()
    seq = self.sequence
    idx = seq.index(seq[-1])
    return seq[idx, seq.length - idx]
  end
  
  def to_i()
    return @number
  end
  def to_s()
    return @number.to_s
  end
end; nil

# %%
k1 = Kaprekar.new(198)
[k1,k1.next, k1.get_prevs]
# Out:
# [198, 792, [102, 113, 120, 123, 131, 132, 133, 200, 201, 202, 210, 213, 220, 224, 231, 234, 242, 243, 244, 311, 312, 313, 321, 324, 331, 335, 342, 345, 353, 354, 355, 422, 423, 424, 432, 435, 442, 446, 453, 456, 464, 465, 466, 533, 534, 535, 543, 546, 553, 557, 564, 567, 575, 576, 577, 644, 645, 646, 654, 657, 664, 668, 675, 678, 686, 687, 688, 755, 756, 757, 765, 768, 775, 779, 786, 789, 797, 798, 799, 866, 867, 868, 876, 879, 886, 897, 977, 978, 979, 987, 997]]

# %%
kp = Kaprekar.new(102)
[kp.sequence, kp.find_loop]
# Out:
# [[102, 198, 792, 693, 594, 495], [495]]

# %%
nn = 10**2
(nn..nn*10).each_with_object([]) do |n, a|
  kp = Kaprekar.new(n)
  mystr = kp.number.to_s
  while !a.include?(kp)
    a << kp
    kp = Kaprekar.new(kp.next)
    mystr += '->'+ kp.number.to_s
  end
  p mystr
end; nil
# Out:
# "100->99->0->0"
# "101->99"
# "102->198->792->693->594->495->495"
# "103->297->693"
# "104->396->594"
# "105->495"
# "106->594"
# "107->693"
# "108->792"
# "109->891->792"
# "110->99"
# "111->0"
# "112->99"
# "113->198"
# "114->297"
# "115->396"
# "116->495"
# "117->594"
# "118->693"
# "119->792"
# "120->198"
# "121->99"
# "122->99"
# "123->198"
# "124->297"
# "125->396"
# "126->495"
# "127->594"
# "128->693"
# "129->792"
# "130->297"
# "131->198"
# "132->198"
# "133->198"
# "134->297"
# "135->396"
# "136->495"
# "137->594"
# "138->693"
# "139->792"
# "140->396"
# "141->297"
# "142->297"
# "143->297"
# "144->297"
# "145->396"
# "146->495"
# "147->594"
# "148->693"
# "149->792"
# "150->495"
# "151->396"
# "152->396"
# "153->396"
# "154->396"
# "155->396"
# "156->495"
# "157->594"
# "158->693"
# "159->792"
# "160->594"
# "161->495"
# "162->495"
# "163->495"
# "164->495"
# "165->495"
# "166->495"
# "843->495"
# "844->396"
# "845->396"
# "846->396"
# "847->396"
# "848->396"
# "849->495"
# "850->792"
# "851->693"
# "852->594"
# "853->495"
# "854->396"
# "855->297"
# "856->297"
# "857->297"
# "858->297"
# "859->396"
# "860->792"
# "861->693"
# "862->594"
# "863->495"
# "864->396"
# "865->297"
# "866->198"
# "867->198"
# "868->198"
# "869->297"
# "870->792"
# "871->693"
# "872->594"
# "873->495"
# "874->396"
# "875->297"
# "876->198"
# "877->99"
# "878->99"
# "879->198"
# "880->792"
# "881->693"
# "882->594"
# "883->495"
# "884->396"
# "885->297"
# "886->198"
# "887->99"
# "888->0"
# "889->99"
# "890->891"
# "891"
# "892->693"
# "893->594"
# "894->495"
# "895->396"
# "896->297"
# "897->198"
# "898->99"
# "899->99"
# "900->891"
# "901->891"
# "902->891"
# "903->891"
# "904->891"
# "905->891"
# "906->891"
# "907->891"
# "908->891"
# "909->891"
# "910->891"
# "911->792"
# "912->792"
# "913->792"
# "914->792"
# "915->792"
# "916->792"
# "917->792"
# "918->792"
# "919->792"
# "920->891"
# "921->792"
# "922->693"
# "923->693"
# "924->693"
# "925->693"
# "926->693"
# "927->693"
# "928->693"
# "929->693"
# "930->891"
# "931->792"
# "932->693"
# "933->594"
# "934->594"
# "935->594"
# "936->594"
# "937->594"
# "938->594"
# "939->594"
# "940->891"
# "941->792"
# "942->693"
# "943->594"
# "944->495"
# "945->495"
# "946->495"
# "947->495"
# "948->495"
# "949->495"
# "950->891"
# "951->792"
# "952->693"
# "953->594"
# "954->495"
# "955->396"
# "956->396"
# "957->396"
# "958->396"
# "959->396"
# "960->891"
# "961->792"
# "962->693"
# "963->594"
# "964->495"
# "965->396"
# "966->297"
# "967->297"
# "968->297"
# "969->297"
# "970->891"
# "971->792"
# "972->693"
# "973->594"
# "974->495"
# "975->396"
# "976->297"
# "977->198"
# "978->198"
# "979->198"
# "980->891"
# "981->792"
# "982->693"
# "983->594"
# "984->495"
# "985->396"
# "986->297"
# "987->198"
# "988->99"
# "989->99"
# "990->891"
# "991->792"
# "992->693"
# "993->594"
# "994->495"
# "995->396"
# "996->297"
# "997->198"
# "998->99"
# "999->0"
# "1000->999"

# %% [markdown]
# ## Display Kaprekar Tree

# %%
class KpTree
  def initialize(kp, maxdepth=10)
    @root = kp
    @subtree = self.maketree(maxdepth)
  end
  
  def show(stack=[], indent=0, keisen='├─ ')
    branch = (indent==0) ? '' : ' '*(2+5*(indent-1)) + keisen
    unless stack.include?(@root.number)
      puts branch + @root.to_s
      stack << @root.number
      unless @subtree.nil?
        @subtree.each_with_index do |c, idx|
          keisen = '└─ ' if idx==@subtree.size-1
          c.show(stack, indent+1, keisen)
        end
      end
    else
      puts branch + "(#{@root.to_s})"
    end
    return stack
  end
  
  protected
  def maketree(maxdepth=10)
    children = @root.get_prevs
    unless (children.empty? or maxdepth==0) then
      subtree = children.map{|c| self.class.new(Kaprekar.new(c), maxdepth-1) }
    end
    return subtree
  end
end; nil

# %%
kp = Kaprekar.new(62)
p kp.sequence
KpTree.new(kp).show
nil
# Out:
# [62, 36, 27, 45, 9, 0]
# 62

# %%
p, q, e = 5, 7, 5

# %%
for m in range(p*q):
    r = (m**e)%(p*q)
    print(f"{m} --> {r}")
# Out:
# 0 --> 0
# 1 --> 1
# 2 --> 32
# 3 --> 33
# 4 --> 9
# 5 --> 10
# 6 --> 6
# 7 --> 7
# 8 --> 8
# 9 --> 4
# 10 --> 5
# 11 --> 16
# 12 --> 17
# 13 --> 13
# 14 --> 14
# 15 --> 15
# 16 --> 11
# 17 --> 12
# 18 --> 23
# 19 --> 24
# 20 --> 20
# 21 --> 21
# 22 --> 22
# 23 --> 18
# 24 --> 19
# 25 --> 30
# 26 --> 31
# 27 --> 27
# 28 --> 28
# 29 --> 29
# 30 --> 25
# 31 --> 26
# 32 --> 2
# 33 --> 3
# 34 --> 34

# %%
D*11+
